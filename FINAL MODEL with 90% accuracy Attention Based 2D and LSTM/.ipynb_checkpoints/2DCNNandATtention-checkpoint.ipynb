# %% [markdown]
# # Import Libraries

# %%
# Keras
# !pip install keras_self_attention
import keras
from keras import regularizers
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential, Model, model_from_json, load_model
from keras.layers import Dense, Embedding, LSTM, Reshape, Bidirectional
from keras.layers import Input, Flatten, Dropout, Activation, BatchNormalization
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D, Conv2D, MaxPooling2D
from keras.utils import np_utils
from keras.callbacks import (EarlyStopping, LearningRateScheduler,
                             ModelCheckpoint, TensorBoard, ReduceLROnPlateau)
from keras import losses, models, optimizers
from keras.activations import relu, softmax
from keras.layers import (Convolution2D, GlobalAveragePooling2D, BatchNormalization, Flatten, Dropout,
                          GlobalMaxPool2D, MaxPool2D, concatenate, Activation, Input, Dense, TimeDistributed)
from keras_self_attention import SeqSelfAttention
from tensorflow.keras.utils import to_categorical, custom_object_scope
import tensorflow as tf
from tensorflow.keras import layers
#tf.keras.layers.Attention
# sklearn
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder


# Other  
from tqdm import tqdm, tqdm_pandas
import scipy
from scipy.stats import skew
import librosa
import librosa.display
import json
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from matplotlib.pyplot import specgram
import pandas as pd
import seaborn as sns
import glob 
import os
import sys
import pickle
import IPython.display as ipd  # To play sound in the notebook
import warnings

# ignore warnings 
if not sys.warnoptions:
    warnings.simplefilter("ignore")
    
print("Executed")
# Out:
# Requirement already satisfied: keras_self_attention in c:\users\jagjeet\anaconda3\envs\applicationml1\lib\site-packages (0.51.0)
# Requirement already satisfied: numpy in c:\users\jagjeet\anaconda3\envs\applicationml1\lib\site-packages (from keras_self_attention) (1.18.5)

# %%
#save dataset file name as below 
file_name = "Audio_Speech_Actors_01-24"
file_nameS = "ALL"
file_nameT = "TESS2"
#save path of dataset in to a variable
Ravdess = os.path.join(os.getcwd(),file_name)
Savee = os.path.join(os.getcwd(),file_nameS)
Tess = os.path.join(os.getcwd(),file_nameT)

print(Ravdess)
print("Executed Successfully")
# Out:
# C:\Users\Jagjeet\AppML\Major Project Final\Pro_1.9_All_Datasets_Spectral_Attention Try\Audio_Speech_Actors_01-24
# Executed Successfully

# %%
# ravdess_directory_list stores the list of present in the provided path
# os.listdir helps in storing the list of data
ravdess_directory_list = os.listdir(Ravdess)
file_emotion = []
file_path = []
#file_gender = []
source = []
for dir in ravdess_directory_list:
    # as their are 20 different actors in our previous directory we need to extract files for each actor.
    # go through each audio clip of the actor
    actor = os.listdir(Ravdess + '/'+ dir)
    for file in actor:
        # split the name from ".", then use the first part
        part = file.split('.')[0]
        # eg :- in 02-01-06-01-02-01-12.mp4, part will store 02-01-06-01-02-01-12 and ignore mp4
        # then again, split the name from "-"
        part = part.split('-')
        # eg :- in 02-01-06-01-02-01-12.mp4,part will store a list containing 02, 01, 06, 01, 02, 01, 12
        # third part in each file represents the emotion associated to that file.
        file_emotion.append(int(part[2]))
        file_path.append(Ravdess + '/' + dir + '/' + file)
        source.append('RAVDE')
    #temp = dir.split('_')[1]
    #if temp%2 == 0:
     #   temp = "Female"
    #else:
     #   remp = "Male"
    #file_gender.append(temp)   
# dataframe for emotion of files
# create a data frame with each row containing file_emotion list contents and its header name Emotions
emotion_df = pd.DataFrame(file_emotion, columns=['label'])
# dataframe for path of files.
# create a data frame with each row containing file_path list contents and its header name Path
path_df = pd.DataFrame(file_path, columns=['path'])
source = pd.DataFrame(source, columns=['source'])
# concatinate emotion_df and path_df data frame and store it in Ravedess_df
Ravdess_df = pd.concat([emotion_df, source, path_df], axis=1)
# changing integers to actual emotions.
Ravdess_df.label.replace({1:'neutral', 2:'calm', 3:'happy', 4:'sad', 5:'angry', 6:'fear', 7:'disgust', 8:'surprise'}, inplace=True)
Ravdess_df.head()


tess_directory_list = os.listdir(Tess)
file_emotion = []
file_path = []
source = []
for dir in tess_directory_list:
    directories = os.listdir(Tess +'/'+ dir)
    for file in directories:
        part = file.split('.')[0]
        # eg:- YAF_back_ps.wav, use YAF_back_ps and ignore wav
        part = part.split('_')[2]
        # in YAF_back_ps, use ps and ignore rest
        if part=='ps':
            file_emotion.append('surprise')
            # eg:- YAF_back_ps.wav is emotion of surprise
        else:
            file_emotion.append(part)
            # whatever the string is becomes the emotion
        file_path.append(Tess + '/'+ dir + '/' + file)
        source.append('TESS')   
# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['label'])
# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['path'])
source_df = pd.DataFrame(source, columns=['source'])
Tess_df = pd.concat([emotion_df, source_df, path_df], axis=1)
Tess_df.head()



savee_directory_list = os.listdir(Savee)
file_emotion = []
file_path = []
source = []
for file in savee_directory_list:
    file_path.append(Savee + '/' + file)
    part = file.split('_')[1]
    ele = part[:-6]
    if ele=='a':
        file_emotion.append('angry')
    elif ele=='d':
        file_emotion.append('disgust')
    elif ele=='f':
        file_emotion.append('fear')
    elif ele=='h':
        file_emotion.append('happy')
    elif ele=='n':
        file_emotion.append('neutral')
    elif ele=='sa':
        file_emotion.append('sad')
    else:
        file_emotion.append('surprise')
    source.append('SAVEE')
# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['label'])
# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['path'])
source_df = pd.DataFrame(source, columns=['source'])
Savee_df = pd.concat([emotion_df, source_df, path_df], axis=1)
Savee_df.head()

# creating Dataframe using all the 4 dataframes we created so far.
data_path = pd.concat([Ravdess_df, Tess_df, Savee_df], axis = 0, ignore_index = True)
data_path.to_csv("data_path.csv",index=True)
ref = data_path.copy()
ref

print("Data Path added to CSV")
# Out:
# Data Path added to CSV

# %% [markdown]
# # Data Augmentation Function

# %%
def noise(data):
    """
    Adding White Noise.
    """
    # you can take any distribution from https://docs.scipy.org/doc/numpy-1.13.0/reference/routines.random.html
    noise_amp = 0.05*np.random.uniform()*np.amax(data)   # more noise reduce the value to 0.5
    data = data.astype('float64') + noise_amp * np.random.normal(size=data.shape[0])
    return data
    

def speedNpitch(data):
    #Speed and Pitch Tuning.
    # you can change low and high here
    length_change = np.random.uniform(low=0.8, high = 1)
    speed_fac = 1.2  / length_change # try changing 1.0 to 2.0 ... =D
    tmp = np.interp(np.arange(0,len(data),speed_fac),np.arange(0,len(data)),data)
    minlen = min(data.shape[0], tmp.shape[0])
    data *= 0
    data[0:minlen] = tmp[0:minlen]
    return data

print("Augmentation function setup successfully")
# Out:
# Augmentation function setup successfully

# %% [markdown]
# # Data Preparation

# %%
def CNN_1D_prepare_data(ref, n_mfcc, audio_duration, aug):
    if aug == 1:
        df = pd.DataFrame(columns=['feature'])
        df_noise = pd.DataFrame(columns=['feature'])
        df_speedpitch = pd.DataFrame(columns=['feature'])
        cnt = 0
        # loop feature extraction over the entire dataset
        for i in tqdm(ref.path):

            # first load the audio 
            X, sample_rate = librosa.load(i
                                          , res_type='kaiser_fast'
                                          ,duration=audio_duration
                                          ,sr=44100
                                          ,offset=0.5
                                         )

            # take mfcc and mean as the feature. Could do min and max etc as well. 
            mfccs = np.mean(librosa.feature.mfcc(y=X, 
                                                sr=np.array(sample_rate), 
                                                n_mfcc=n_mfcc),
                            axis=0)

            df.loc[cnt] = [mfccs]  
            # random shifting (omit for now)
            # Stretch
            # pitch (omit for now)
            # dyn change

            # noise 
            aug = noise(X)
            aug = np.mean(librosa.feature.mfcc(y=aug, 
                                            sr=np.array(sample_rate), 
                                            n_mfcc=n_mfcc),    
                          axis=0)
            df_noise.loc[cnt] = [aug]

            # speed pitch
            aug = speedNpitch(X)
            aug = np.mean(librosa.feature.mfcc(y=aug, 
                                            sr=np.array(sample_rate), 
                                            n_mfcc=n_mfcc),    
                          axis=0)
            df_speedpitch.loc[cnt] = [aug]   

            cnt += 1

        df = pd.concat([ref,pd.DataFrame(df['feature'].values.tolist())],axis=1)
        df_noise = pd.concat([ref,pd.DataFrame(df_noise['feature'].values.tolist())],axis=1)
        df_speedpitch = pd.concat([ref,pd.DataFrame(df_speedpitch['feature'].values.tolist())],axis=1)
        print(df.shape,df_noise.shape,df_speedpitch.shape)
        df = pd.concat([df,df_noise,df_speedpitch],axis=0,sort=False)
        df=df.fillna(0)
        del df_noise, df_speedpitch

        return df
        

    else:
        # loop feature extraction over the entire dataset
        df = pd.DataFrame(columns=['feature'])
        counter=0
        for path in tqdm(ref.path):
            X, sample_rate = librosa.load(path
                                          , res_type='kaiser_fast'
                                          ,duration=audio_duration
                                          ,sr=44100
                                          ,offset=0.5
                                         )
            sample_rate = np.array(sample_rate)

            # mean as the feature. Could do min and max etc as well. 
            mfccs = np.mean(librosa.feature.mfcc(y=X, 
                                                sr=sample_rate, 
                                                n_mfcc=n_mfcc),
                            axis=0)
            df.loc[counter] = [mfccs]
            counter=counter+1   

        df = pd.concat([ref,pd.DataFrame(df['feature'].values.tolist())],axis=1)
        df = df.fillna(0)
        return df



# Extracting the MFCC feature as an image (Matrix format).  
def CNN_2D_prepare_data(df, n, aug, mfcc):
    
    X = np.empty(shape=(df.shape[0], n, 216, 1))
    input_length = sampling_rate * audio_duration
    
    cnt = 0
    for fname in tqdm(df.path):
        file_path = fname
        data, _ = librosa.load(file_path, sr=sampling_rate
                               ,res_type="kaiser_fast"
                               ,duration=2.5
                               ,offset=0.5
                              )

        # Random offset / Padding
        if len(data) > input_length:
            max_offset = len(data) - input_length
            offset = np.random.randint(max_offset)
            data = data[offset:(input_length+offset)]
        else:
            if input_length > len(data):
                max_offset = input_length - len(data)
                offset = np.random.randint(max_offset)
            else:
                offset = 0
            data = np.pad(data, (offset, int(input_length) - len(data) - offset), "constant")

        # Augmentation? 
        if aug == 1:
            data = speedNpitch(data)
        
        # which feature?
        if mfcc == 1:
            # MFCC extraction 
            MFCC = librosa.feature.mfcc(data, sr=sampling_rate, n_mfcc=n_mfcc)
            MFCC = np.expand_dims(MFCC, axis=-1)
            X[cnt,] = MFCC
            
        else:
            # Log-melspectogram
            melspec = librosa.feature.melspectrogram(data, n_mels = n_melspec)   
            logspec = librosa.amplitude_to_db(melspec)
            logspec = np.expand_dims(logspec, axis=-1)
            X[cnt,] = logspec
            
        cnt += 1
    
    return X

def CNN_2D_prepare_data2(df, n, aug, mfcc):
    
    X = np.empty(shape=(df.shape[0], n, 216, 1))
    input_length = sampling_rate * audio_duration
    
    cnt = 0
    for fname in tqdm(df.path):
        file_path = fname
        data, _ = librosa.load(file_path, sr=sampling_rate
                               ,res_type="kaiser_fast"
                               ,duration=2.5
                               ,offset=0.5
                              )

        # Random offset / Padding
        if len(data) > input_length:
            max_offset = len(data) - input_length
            offset = np.random.randint(max_offset)
            data = data[offset:(input_length+offset)]
        else:
            if input_length > len(data):
                max_offset = input_length - len(data)
                offset = np.random.randint(max_offset)
            else:
                offset = 0
            data = np.pad(data, (offset, int(input_length) - len(data) - offset), "constant")

        # Augmentation? 
        if aug == 1:
            data = noise(data)
        
        # which feature?
        if mfcc == 1:
            # MFCC extraction 
            MFCC = librosa.feature.mfcc(data, sr=sampling_rate, n_mfcc=n_mfcc)
            MFCC = np.expand_dims(MFCC, axis=-1)
            X[cnt,] = MFCC
            
        else:
            # Log-melspectogram
            melspec = librosa.feature.melspectrogram(data, n_mels = n_melspec)   
            logspec = librosa.amplitude_to_db(melspec)
            logspec = np.expand_dims(logspec, axis=-1)
            X[cnt,] = logspec
            
        cnt += 1
    
    return X
   
    
def data_normalization(X_train, X_test, X_val):
    # Lts do data normalization 
    mean = np.mean(X_train, axis=0)
    std = np.std(X_train, axis=0)

    X_train_norm = (X_train - mean)/std
    X_test_norm = (X_test - mean)/std
    X_val_norm = (X_val - mean)/std
    
    return X_train_norm, X_test_norm, X_val_norm

def np_array_conversation(X_train, y_train, X_test, y_test, X_val, y_val):
    # Lets few preparation steps to get it into the correct format for Keras 

    X_train = np.array(X_train)
    y_train = np.array(y_train)
    X_test = np.array(X_test)
    y_test = np.array(y_test)
    X_val = np.array(X_val)
    y_val = np.array(y_val)
    #print(X_train.shape)
    
    return X_train, y_train, X_test, y_test, X_val, y_val

print("Preprocessed")
# Out:
# Preprocessed

# %% [markdown]
# # Function Related To Results

# %%
def print_confusion_matrix(confusion_matrix, class_names, figsize = (10,7), fontsize=14):
    
    df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names)
    fig = plt.figure(figsize=figsize)
    try:
        #heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
        heatmap = sns.heatmap(df_cm, annot=True, fmt='.2%')

    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")

    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
class get_results:

    def __init__(self, model_history, model ,X_test_norm, y_test_cat, labels):
        self.model_history = model_history
        self.model = model
        self.X_test_norm = X_test_norm
        self.y_test_cat = y_test_cat             
        self.labels = labels

    def create_plot(self, model_history):
        '''Check the logloss of both train and validation, make sure they are close and have plateau'''
        plt.plot(model_history.history['loss'])
        plt.plot(model_history.history['val_loss'])
        plt.title('model loss')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()
        
        plt.plot(model_history.history['acc'])
        plt.plot(model_history.history['val_acc'])
        plt.title('model accuracy')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()


    def create_results(self, model):
        '''predict on test set and get accuracy results'''
        opt = tf.keras.optimizers.SGD(learning_rate=0.0001, decay=1e-6, momentum=0.9, nesterov=True)
        model.compile(optimizer=opt, loss=losses.categorical_crossentropy, metrics=['acc'])
        test_loss, test_acc = model.evaluate(X_test_norm, y_test_cat, verbose=0)
        print("Test Accuracy: ",test_acc)
        print("Test loss: ",test_loss) 
        score = model.evaluate(X_test_norm, y_test_cat, verbose=1)
        print("%s: %.2f%%" % (model.metrics_names[1], score[1]*100))
            

    def confusion_results(self, X_test_norm, y_test_cat, labels, model):
        preds = model.predict(X_test_norm, 
                              batch_size=16, 
                              verbose=1)
        preds=preds.argmax(axis=1)
        preds = preds.astype(int).flatten()
        preds = (lb.inverse_transform((preds)))
        preds = pd.DataFrame({'predictedvalues': preds})# new temp code
        
        actual = y_test_cat.argmax(axis=1)
        actual = actual.astype(int).flatten()
        actual = (lb.inverse_transform((actual)))
        actual = pd.DataFrame({'actualvalues': actual}) ## new temp code
        
        finaldf = actual.join(preds)
        print(finaldf[170:180])     
        
        # Write out the predictions to disk
        finaldf.to_csv('Predictions.csv', index=False)
        print(finaldf.groupby('predictedvalues').count())
        
        classes = labels
        classes.sort()    
        cm = confusion_matrix(actual, preds)
        cmn = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print_confusion_matrix(cmn, class_names = classes)

        return finaldf
    
print("Result functions created")
# Out:
# Result functions created

# %% [markdown]
# # Dataset Visualization

# %%
def create_waveplot(data, sr, e):
    plt.figure(figsize=(10, 3))
    # {} will store the string, written outside the single quote
    plt.title('Waveplot for audio with {} emotion'.format(e), size=15)
    librosa.display.waveplot(data, sr=sr)
    plt.show()

def create_spectrogram(data, sr, e):
    # stft function converts the data into short term fourier transform
    X = librosa.stft(data)
    # Python abs() function is used to return the absolute value of a number, i.e., it will remove the negative sign of the number.  
    # librosa.amplitude_to_db Convert an amplitude spectrogram to dB-scaled spectrogram.
    Xdb = librosa.amplitude_to_db(abs(X))
    plt.figure(figsize=(12, 3))
    plt.title('Spectrogram for audio with {} emotion'.format(e), size=15)
    librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')   
    #librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
    plt.colorbar()

emotion='angry'
path = np.array(ref.path[data_path.label==emotion])[1]
data, sampling_rate = librosa.load(path)
create_waveplot(data, sampling_rate, emotion)
create_spectrogram(data, sampling_rate, emotion)

emotion='happy'
path = np.array(ref.path[data_path.label==emotion])[1]
data, sampling_rate = librosa.load(path)
create_waveplot(data, sampling_rate, emotion)
create_spectrogram(data, sampling_rate, emotion)

# %% [markdown]
# # 2D CNN MFCC without Augmentation

# %%
sampling_rate=44100
audio_duration=2.5
n_mfcc = 30
aug = 0
mfcc = CNN_2D_prepare_data(ref, n_mfcc, aug, mfcc = 1)    # mfcc = 0  means MFCC conversion will be used
# Out:
# 100%|██████████| 4720/4720 [05:21<00:00, 14.69it/s]

# %%
# Split between train and test 
X_train, X_test, y_train, y_test = train_test_split(mfcc
                                                    , ref.label
                                                    , test_size=0.25
                                                    , shuffle=True
                                                    , random_state=42
                                                   )

X_train, X_val, y_train, y_val = train_test_split(X_train
                                                  , y_train
                                                  , test_size=0.25
                                                  , shuffle=True
                                                  , random_state=42
                                                 )
print("split successfully")
# Out:
# split successfully

# %% [markdown]
# 2D CNN Model

# %%
def get_2d_conv_model(n):
    ''' Create a standard deep 2D convolutional neural network'''
    nclass = 8
    inp = Input(shape=(n,216,1))  #2D matrix of 30 MFCC bands by 216 audio length.
    x = Convolution2D(64, (3,3), strides=(1, 1), padding="same")(inp)    #(4,10)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPool2D()(x)
    x = Dropout(rate=0.2)(x)
    
    x = Convolution2D(128, (3,3), strides=(1, 1), padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPool2D()(x)
    x = Dropout(rate=0.2)(x)
    
    x = Convolution2D(256, (3,3), strides=(1, 1), padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPool2D()(x)
    x = Dropout(rate=0.2)(x)
    
    x = Convolution2D(128, (3,3), strides=(1, 1), padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPool2D()(x)
    x = Dropout(rate=0.2)(x)
    
    x = Flatten()(x)
    
    out = Dense(nclass, activation=softmax)(x)
    model = models.Model(inputs=inp, outputs=out)
    
    opt = tf.keras.optimizers.Adam(learning_rate = 0.0001, decay=1e-6)
    model.compile(optimizer=opt, loss=losses.categorical_crossentropy, metrics=['acc'])
    return model

# Normalization as per the standard NN process
X_train_norm, X_test_norm, X_val_norm = data_normalization(X_train, X_test, X_val)

# one hot encode the target 
lb = LabelEncoder()
y_train_cat = np_utils.to_categorical(lb.fit_transform(y_train))    # for GPU
y_test_cat = np_utils.to_categorical(lb.fit_transform(y_test))      # for GPU
y_val_cat = np_utils.to_categorical(lb.fit_transform(y_val))        # for GPU

#y_train = to_categorical(lb.fit_transform(y_train)) # for TPU
#y_test = to_categorical(lb.fit_transform(y_test))   # for TPU
#y_val = to_categorical(lb.fit_transform(y_val))     # for TPU

print(X_train.shape)
print(lb.classes_)

model = get_2d_conv_model(n_mfcc)
model.summary()

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=15)
model_name = 'best_model.h5'
save_dir = os.path.join(os.getcwd(), 'saved_models')
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
print('Save model and weights at %s ' % model_path)
mc = ModelCheckpoint(model_path, monitor='val_acc', mode='max', verbose=1, 
                     save_best_only=True)
model_history = model.fit(X_train_norm, y_train_cat, validation_data=(X_val_norm, y_val_cat), batch_size=32,
                          verbose = 1, epochs=35, callbacks=[es, mc])

results = get_results(model_history,model,X_test_norm,y_test_cat, ref.label.unique())
results.create_plot(model_history)

model_json = model.to_json()
with open("model_json.json", "w") as json_file:
    json_file.write(model_json)

# loading json and model architecture 
json_file = open('model_json.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
from keras.models import model_from_json
loaded_model = model_from_json(loaded_model_json, custom_objects={'SeqSelfAttention': SeqSelfAttention})

# load weights into new model
loaded_model.load_weights(model_path)#("saved_models/best_model.h5")
print("Loaded model from disk")

results.create_results(loaded_model)
finaldf = results.confusion_results(X_test_norm, y_test_cat, ref.label.unique(), loaded_model)

# Classification report 
classes = finaldf.actualvalues.unique()
classes.sort()    
print(classification_report(finaldf.actualvalues, finaldf.predictedvalues, target_names=classes))
# Out:
# (2655, 30, 216, 1)
# ['angry' 'calm' 'disgust' 'fear' 'happy' 'neutral' 'sad' 'surprise']
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 30, 216, 1)]      0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 30, 216, 64)       640
# _________________________________________________________________
# batch_normalization (BatchNo (None, 30, 216, 64)       256
# _________________________________________________________________
# activation (Activation)      (None, 30, 216, 64)       0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 108, 64)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 15, 108, 64)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 15, 108, 128)      73856
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 15, 108, 128)      512
# _________________________________________________________________
# activation_1 (Activation)    (None, 15, 108, 128)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 54, 128)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 54, 128)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 54, 256)        295168
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 7, 54, 256)        1024
# _________________________________________________________________
# activation_2 (Activation)    (None, 7, 54, 256)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 3, 27, 256)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 3, 27, 256)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 27, 128)        295040
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 3, 27, 128)        512
# _________________________________________________________________
# activation_3 (Activation)    (None, 3, 27, 128)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 13, 128)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 13, 128)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 1664)              0
# _________________________________________________________________
# dense (Dense)                (None, 8)                 13320
# =================================================================
# Total params: 680,328
# Trainable params: 679,176
# Non-trainable params: 1,152
# _________________________________________________________________
# Save model and weights at C:\Users\Jagjeet\AppML\Major Project Final\Pro_1.9_All_Datasets_Spectral_Attention Try\saved_models\best_model.h5
# Epoch 1/35
# 83/83 [==============================] - ETA: 0s - loss: 2.2118 - acc: 0.2377
# Epoch 00001: val_acc improved from -inf to 0.16158, saving model to C:\Users\Jagjeet\AppML\Major Project Final\Pro_1.9_All_Datasets_Spectral_Attention Try\saved_models\best_model.h5
# 83/83 [==============================] -
35
# 83/83 [==============================] - ETA: 0s - loss: 0.3733 - acc: 0.8712
# Epoch 00026: val_acc did not improve from 0.81243
# 83/83 [==============================] - 232s 3s/step - loss: 0.3733 - acc: 0.8712 - val_loss: 0.6255 - val_acc: 0.7898
# Epoch 27/35
# 83/83 [==============================] - ETA: 0s - loss: 0.3710 - acc: 0.8727
# Epoch 00027: val_acc improved from 0.81243 to 0.82147, saving model to C:\Users\Jagjeet\AppML\Major Project Final\Pro_1.9_All_Datasets_Spectral_Attention Try\saved_models\best_model.h5
# 83/83 [==============================] - 226s 3s/step - loss: 0.3710 - acc: 0.8727 - val_loss: 0.4927 - val_acc: 0.8215
# Epoch 28/35
# 83/83 [==============================] - ETA: 0s - loss: 0.3547 - acc: 0.8780
# Epoch 00028: val_acc improved from 0.82147 to 0.82373, saving model to C:\Users\Jagjeet\AppML\Major Project Final\Pro_1.9_All_Datasets_Spectral_Attention Try\saved_models\best_model.h5
# 83/83 [==============================] - 251s 3s/step - loss: 0.3547 - acc: 0.8780 - val_loss: 0.4934 - val_acc: 0.8237
# Epoch 29/35
# 83/83 [==============================] - ETA: 0s - loss: 0.3389 - acc: 0.8878
# Epoch 00029: val_acc improved from 0.82373 to 0.82486, saving model to C:\Users\Jagjeet\AppML\Major Project Final\Pro_1.9_All_Datasets_Spectral_Attention Try\saved_models\best_model.h5
# 83/83 [==============================] - 214s 3s/step - loss: 0.3389 - acc: 0.8878 - val_loss: 0.4866 - val_acc: 0.8249
# Epoch 30/35
# 83/83 [==============================] - ETA: 0s - loss: 0.3176 - acc: 0.8976
# Epoch 00030: val_acc did not improve from 0.82486
# 83/83 [==============================] - 212s 3s/step - loss: 0.3176 - acc: 0.8976 - val_loss: 0.5627 - val_acc: 0.8090
# Epoch 31/35
# 83/83 [==============================] - ETA: 0s - loss: 0.3019 - acc: 0.9006
# Epoch 00031: val_acc did not improve from 0.82486
# 83/83 [==============================] - 208s 3s/step - loss: 0.3019 - acc: 0.9006 - val_loss: 0.4963 - val_acc: 0.8237
# Epoch 32/35
# 83/83 [==============================] - ETA: 0s - loss: 0.2771 - acc: 0.9096
# Epoch 00032: val_acc improved from 0.82486 to 0.83616, saving model to C:\Users\Jagjeet\AppML\Major Project Final\Pro_1.9_All_Datasets_Spectral_Attention Try\saved_models\best_model.h5
# 83/83 [==============================] - 213s 3s/step - loss: 0.2771 - acc: 0.9096 - val_loss: 0.4613 - val_acc: 0.8362
# Epoch 33/35
# 83/83 [==============================] - ETA: 0s - loss: 0.2731 - acc: 0.9100
# Epoch 00033: val_acc did not improve from 0.83616
# 83/83 [==============================] - 203s 2s/step - loss: 0.2731 - acc: 0.9100 - val_loss: 0.4821 - val_acc: 0.8271
# Epoch 34/35
# 83/83 [==============================] - ETA: 0s - loss: 0.2456 - acc: 0.9254
# Epoch 00034: val_acc did not improve from 0.83616
# 83/83 [==============================] - 213s 3s/step - loss: 0.2456 - acc: 0.9254 - val_loss: 0.4500 - val_acc: 0.8350
# Epoch 35/35
# 83/83 [==============================] - ETA: 0s - loss: 0.2582 - acc: 0.9175
# Epoch 00035: val_acc did not improve from 0.83616
# 83/83 [==============================] - 214s 3s/step - loss: 0.2582 - acc: 0.9175 - val_loss: 0.4590 - val_acc: 0.8260
# Loaded model from disk
# Test Accuracy:  0.8059322237968445
# Test loss:  0.5355402827262878
# 37/37 [==============================] - 12s 317ms/step - loss: 0.5355 - acc: 0.8059
# acc: 80.59%
# 74/74 [==============================] - 13s 170ms/step
#     actualvalues predictedvalues
# 170      disgust           angry
# 171         fear            fear
# 172         calm            calm
# 173      disgust             sad
# 174          sad             sad
# 175     surprise        surprise
# 176     surprise         neutral
# 177      disgust         disgust
# 178        happy             sad
# 179         fear           happy
#                  actualvalues
# predictedvalues
# angry                     160
# calm                       62
# disgust                   165
# fear                      141
# happy                     166
# neutral                   147
# sad                       197
# surprise                  142
#               precision    recall  f1-score   support
#
#        angry       0.89      0.81      0.85       175
#         calm       0.60      0.79      0.68        47
#      disgust       0.80      0.86      0.83       154
#         fear       0.92      0.77      0.84       169
#        happy       0.75      0.79      0.77       157
#      neutral       0.86      0.84      0.85       150
#          sad       0.70      0.83      0.76       165
#     surprise       0.87      0.75      0.81       163
#
#     accuracy                           0.81      1180
#    macro avg       0.80      0.80      0.80      1180
# weighted avg       0.82      0.81      0.81      1180

# %% [markdown]
# 2D CNN LSTM Model

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
def get_2d_conv_LSTM_model(n):
    ''' Create a standard deep 2D convolutional neural network'''
    nclass = 8
    inp = Input(shape=(n,216,1))  #2D matrix of 30 MFCC bands by 216 audio length.
    x = Convolution2D(64, (3,3), strides=(1, 1), padding="same")(inp)    #(4,10)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPool2D()(x)
    x = Dropout(rate=0.2)(x)
    
    x = Convolution2D(128, (3,3), strides=(1, 1), padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPool2D()(x)
    x = Dropout(rate=0.2)(x)
    
    x = Convolution2D(256, (3,3), strides=(1, 1), padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPool2D()(x)
    x = Dropout(rate=0.2)(x)
    
    x = Convolution2D(128, (3,3), strides=(1, 1), padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPool2D()(x)
    x = Dropout(rate=0.2)(x)
    
    x = Reshape((-1, 128))(x)
    
    #LSTM
    x = LSTM(128)(x)
    
    out = Dense(nclass, activation=softmax)(x)
    model = models.Model(inputs=inp, outputs=out)
    
    opt = tf.keras.optimizers.Adam(learning_rate = 0.0001, decay=1e-6)
    model.compile(optimizer=opt, loss=losses.categorical_crossentropy, metrics=['acc'])
    return model


# Normalization as per the standard NN process
X_train_norm, X_test_norm, X_val_norm = data_normalization(X_train, X_test, X_val)

# one hot encode the target 
lb = LabelEncoder()
y_train_cat = np_utils.to_categorical(lb.fit_transform(y_train))    # for GPU
y_test_cat = np_utils.to_categorical(lb.fit_transform(y_test))      # for GPU
y_val_cat = np_utils.to_categorical(lb.fit_transform(y_val))        # for GPU


print(X_train.shape)
print(lb.classes_)

model = get_2d_conv_LSTM_model(n_mfcc)
model.summary()

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=15)
model_name = 'best_model.h5'
save_dir = os.path.join(os.getcwd(), 'saved_models')
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
print('Save model and weights at %s ' % model_path)
mc = ModelCheckpoint(model_path, monitor='val_acc', mode='max', verbose=1, 
                     save_best_only=True)
model_history = model.fit(X_train_norm, y_train_cat, validation_data=(X_val_norm, y_val_cat), batch_size=32,
                          verbose = 1, epochs=35, callbacks=[es, mc])

results = get_results(model_history,model,X_test_norm,y_test_cat, ref.label.unique())
results.create_plot(model_history)

model_json = model.to_json()
with open("model_json.json", "w") as json_file:
    json_file.write(model_json)

# loading json and model architecture 
json_file = open('model_json.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
from keras.models import model_from_json
loaded_model = model_from_json(loaded_model_json, custom_objects={'SeqSelfAttention': SeqSelfAttention})

# load weights into new model
loaded_model.load_weights(model_path)#("saved_models/best_model.h5")
print("Loaded model from disk")

results.create_results(loaded_model)
finaldf = results.confusion_results(X_test_norm, y_test_cat, ref.label.unique(), loaded_model)

# Classification report 
classes = finaldf.actualvalues.unique()
classes.sort()    
print(classification_report(finaldf.actualvalues, finaldf.predictedvalues, target_names=classes))
# Out:
# (2655, 30, 216, 1)
# ['angry' 'calm' 'disgust' 'fear' 'happy' 'neutral' 'sad' 'surprise']
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 30, 216, 1)]      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 30, 216, 64)       640
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 30, 216, 64)       256
# _________________________________________________________________
# activation_4 (Activation)    (None, 30, 216, 64)       0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 15, 108, 64)       0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 15, 108, 64)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 15, 108, 128)      73856
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 15, 108, 128)      512
# _________________________________________________________________
# activation_5 (Activation)    (None, 15, 108, 128)      0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 7, 54, 128)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 7, 54, 128)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 7, 54, 256)        295168
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 7, 54, 256)        1024
# _________________________________________________________________
# activation_6 (Activation)    (None, 7, 54, 256)        0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 3, 27, 256)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 3, 27, 256)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 3, 27, 128)        295040
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 3, 27, 128)        512
# _________________________________________________________________
# activation_7 (Activation)    (None, 3, 27, 128)        0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 1, 13, 128)        0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 1, 13, 128)        0
# _________________________________________________________________
# reshape (Reshape)            (None, 13, 128)           0
# _________________________________________________________________
# lstm (LSTM)                  (None, 128)               131584
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 1032
# =================================================================
# Total params: 799,624
# Trainable params: 798,472
# Non-trainable params: 1,152
# _________________________________________________________________
# Save model and weights at C:\Users\Jagjeet\AppML\Major Project Final\Pro_1.9_All_Datasets_Spectral_Attention Try\saved_models\best_model.h5
# Epoch 1/35
# 83/83 [==============================] - ETA: 0s - loss: 1.8836 - acc: 0.2795
# Epoch 00001: val_acc improved from -inf to 0.17853, saving model to C:\Users\Jagjeet\AppML\Major Project Final\Pro_1.9_All_Datasets_Spectral_Attention Try\saved_models\best_model.h5
# 83/83 [==============================] - 211s 3s/step - loss: 1.8836 - acc: 0.2795 - val_loss: 2.0247 - val_acc: 0.1785
# Epoch 2/35
# 83/83 [==============================] - ETA: 0s - loss: 1.5215 - acc: 0.4719
# Epoch 00002: val_acc improved from 0.17853 to 0.18870, saving model to C:\Users\Jagjeet\AppML\Major Project Final\Pro_1.9_All_Datasets_Spectral_Attention Try\saved_models\best_model.h5
# 83/83 [==============================] -
35
# 83/83 [==============================] - ETA: 0s - loss: 0.2697 - acc: 0.9107
# Epoch 00029: val_acc did not improve from 0.83390
# 83/83 [==============================] - 222s 3s/step - loss: 0.2697 - acc: 0.9107 - val_loss: 0.4650 - val_acc: 0.8271
# Epoch 30/35
# 83/83 [==============================] - ETA: 0s - loss: 0.2458 - acc: 0.9179
# Epoch 00030: val_acc improved from 0.83390 to 0.83616, saving model to C:\Users\Jagjeet\AppML\Major Project Final\Pro_1.9_All_Datasets_Spectral_Attention Try\saved_models\best_model.h5
# 83/83 [==============================] - 203s 2s/step - loss: 0.2458 - acc: 0.9179 - val_loss: 0.4898 - val_acc: 0.8362
# Epoch 31/35
# 83/83 [==============================] - ETA: 0s - loss: 0.2483 - acc: 0.9160
# Epoch 00031: val_acc did not improve from 0.83616
# 83/83 [==============================] - 219s 3s/step - loss: 0.2483 - acc: 0.9160 - val_loss: 0.5537 - val_acc: 0.8158
# Epoch 32/35
# 83/83 [==============================] - ETA: 0s - loss: 0.2348 - acc: 0.9232
# Epoch 00032: val_acc did not improve from 0.83616
# 83/83 [==============================] - 213s 3s/step - loss: 0.2348 - acc: 0.9232 - val_loss: 0.4461 - val_acc: 0.8339
# Epoch 33/35
# 83/83 [==============================] - ETA: 0s - loss: 0.2265 - acc: 0.9299
# Epoch 00033: val_acc did not improve from 0.83616
# 83/83 [==============================] - 205s 2s/step - loss: 0.2265 - acc: 0.9299 - val_loss: 0.5128 - val_acc: 0.8260
# Epoch 34/35
# 83/83 [==============================] - ETA: 0s - loss: 0.2157 - acc: 0.9269
# Epoch 00034: val_acc did not improve from 0.83616
# 83/83 [==============================] - 202s 2s/step - loss: 0.2157 - acc: 0.9269 - val_loss: 0.5374 - val_acc: 0.8136
# Epoch 35/35
# 83/83 [==============================] - ETA: 0s - loss: 0.1946 - acc: 0.9427
# Epoch 00035: val_acc did not improve from 0.83616
# 83/83 [==============================] - 201s 2s/step - loss: 0.1946 - acc: 0.9427 - val_loss: 0.5341 - val_acc: 0.8305
# Loaded model from disk
# Test Accuracy:  0.8152542114257812
# Test loss:  0.5387917757034302
# 37/37 [==============================] - 13s 358ms/step - loss: 0.5388 - acc: 0.8153
# acc: 81.53%
# 74/74 [==============================] - 14s 189ms/step
#     actualvalues predictedvalues
# 170      disgust         disgust
# 171         fear            fear
# 172         calm         neutral
# 173      disgust         disgust
# 174          sad             sad
# 175     surprise            fear
# 176     surprise           angry
# 177      disgust         disgust
# 178        happy           happy
# 179         fear            fear
#                  actualvalues
# predictedvalues
# angry                     156
# calm                       54
# disgust                   149
# fear                      212
# happy                     196
# neutral                   133
# sad                       172
# surprise                  108
#               precision    recall  f1-score   support
#
#        angry       0.88      0.79      0.83       175
#         calm       0.70      0.81      0.75        47
#      disgust       0.90      0.87      0.88       154
#         fear       0.70      0.88      0.78       169
#        happy       0.67      0.84      0.75       157
#      neutral       0.96      0.85      0.90       150
#          sad       0.81      0.85      0.83       165
#     surprise       0.96      0.64      0.77       163
#
#     accuracy                           0.82      1180
#    macro avg       0.82      0.82      0.81      1180
# weighted avg       0.84      0.82      0.82      1180

# %% [markdown]
# 2D CNN LSTM with self-attention Model

# %%
def get_2d_conv_LSTM_atten_model(n):
    ''' Create a standard deep 2D convolutional neural network'''
    nclass = 8
    inp = Input(shape=(n,216,1))  #2D matrix of 30 MFCC bands by 216 audio length.
    x = Convolution2D(64, (3,3), strides=(1, 1), padding="same")(inp)    #(4,10)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPool2D()(x)
    x = Dropout(rate=0.2)(x)
    
    x = Convolution2D(128, (3,3), strides=(1, 1), padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPool2D()(x)
    x = Dropout(rate=0.2)(x)
    
    x = Convolution2D(256, (3,3), strides=(1, 1), padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPool2D()(x)
    x = Dropout(rate=0.2)(x)
    
    x = Convolution2D(128, (3,3), strides=(1, 1), padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPool2D()(x)
    x = Dropout(rate=0.2)(x)
    
    x = Reshape((-1, 128))(x)
    #LSTM
    x = LSTM(32, return_sequences=True)(x)
    x = SeqSelfAttention(attention_activation ='tanh')(x)
    x = LSTM(32, return_sequences=False)(x)
    
    
    out = Dense(nclass, activation=softmax)(x)
    model = models.Model(inputs=inp, outputs=out)
    
    opt = tf.keras.optimizers.Adam(learning_rate = 0.0001, decay=1e-6)
    model.compile(optimizer=opt, loss=losses.categorical_crossentropy, metrics=['acc'])
    return model


# Normalization as per the standard NN process
X_train_norm, X_test_norm, X_val_norm = data_normalization(X_train, X_test, X_val)

# one hot encode the target 
lb = LabelEncoder()
y_train_cat = np_utils.to_categorical(lb.fit_transform(y_train))    # for GPU
y_test_cat = np_utils.to_categorical(lb.fit_transform(y_test))      # for GPU
y_val_cat = np_utils.to_categorical(lb.fit_transform(y_val))        # for GPU


#y_train = to_categorical(lb.fit_transform(y_train)) # for TPU
#y_test = to_categorical(lb.fit_transform(y_test))   # for TPU
#y_val = to_categorical(lb.fit_transform(y_val))     # for TPU

print(X_train.shape)
print(lb.classes_)

model = get_2d_conv_LSTM_atten_model(n_mfcc)
model.summary()
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=15)
model_name = 'best_model.h5'
save_dir = os.path.join(os.getcwd(), 'saved_models')
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
print('Save model and weights at %s ' % model_path)

mc = ModelCheckpoint(model_path, monitor='val_acc', mode='max', verbose=1, 
                     save_best_only=True)
model_history = model.fit(X_train_norm, y_train_cat, validation_data=(X_val_norm, y_val_cat), batch_size=32,
                          verbose = 1, epochs=35, callbacks=[es, mc])

results = get_results(model_history,model,X_test_norm,y_test_cat, ref.label.unique())
results.create_plot(model_history)

model_json = model.to_json()
with open("model_json.json", "w") as json_file:
    json_file.write(model_json)

# loading json and model architecture 
json_file = open('model_json.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
from keras.models import model_from_json
loaded_model = model_from_json(loaded_model_json, custom_objects={'SeqSelfAttention': SeqSelfAttention})

# load weights into new model
loaded_model.load_weights(model_path)#("saved_models/best_model.h5")
print("Loaded model from disk")

results.create_results(loaded_model)
finaldf = results.confusion_results(X_test_norm,y_test_cat, ref.label.unique(), loaded_model)

# Classification report 
classes = finaldf.actualvalues.unique()
classes.sort()    
print(classification_report(finaldf.actualvalues, finaldf.predictedvalues, target_names=classes))
# Out:
# (2655, 30, 216, 1)
# ['angry' 'calm' 'disgust' 'fear' 'happy' 'neutral' 'sad' 'surprise']
# WARNING:tensorflow:AutoGraph could not transform <bound method SeqSelfAttention.call of <keras_self_attention.seq_self_attention.SeqSelfAttention object at 0x0000015E1B220A90>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method SeqSelfAttention.call of <keras_self_attention.seq_self_attention.SeqSelfAttention object at 0x0000015E1B220A90>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Model: "functional_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 30, 216, 1)]      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 30, 216, 64)       640
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 30, 216, 64)       256
# _________________________________________________________________
# activation_8 (Activation)    (None, 30, 216, 64)       0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 15, 108, 64)       0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 15, 108, 64)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 15, 108, 128)      73856
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 15, 108, 128)      512
# _________________________________________________________________
# activation_9 (Activation)    (None, 15, 108, 128)      0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 7, 54, 128)        0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 7, 54, 128)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 7, 54, 256)        295168
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 7, 54, 256)        1024
# _________________________________________________________________
# activation_10 (Activation)   (None, 7, 54, 256)        0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 3, 27, 256)        0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 3, 27, 256)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 3, 27, 128)        295040
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 3, 27, 128)        512
# _________________________________________________________________
# activation_11 (Activation)   (None, 3, 27, 128)        0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 1, 13, 128)        0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 1, 13, 128)        0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 13, 128)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 13, 32)            20608
# _________________________________________________________________
# seq_self_attention (SeqSelfA (None, None, 32)          2113
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 32)                8320
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 264
# =================================================================
# Total params: 698,313
# Trainable params: 697,161
# Non-trainable params: 1,152
# _________________________________________________________________
# Save model and weights at C:\Users\Jagjeet\AppML\Major Project Final\Pro_1.9_All_Datasets_Spectral_Attention Try\saved_models\best_model.h5
# Epoch 1/35
# 83/83 [==============================] - ETA: 0s - loss: 1.9599 - acc: 0.2501
# Epoch 00001: val_acc improved from -inf to 0.12655, saving model to C:\Users\Jagjeet\AppML\Major Project Final\Pro_1.9_All_Datasets_Spectral_Attention Try\saved_models\best_model.h5
# 83/83 [==============================] -
35
# 83/83 [==============================] - ETA: 0s - loss: 0.3839 - acc: 0.8712
# Epoch 00027: val_acc did not improve from 0.82034
# 83/83 [==============================] - 199s 2s/step - loss: 0.3839 - acc: 0.8712 - val_loss: 0.5467 - val_acc: 0.8147
# Epoch 28/35
# 83/83 [==============================] - ETA: 0s - loss: 0.3869 - acc: 0.8655
# Epoch 00028: val_acc did not improve from 0.82034
# 83/83 [==============================] - 204s 2s/step - loss: 0.3869 - acc: 0.8655 - val_loss: 0.6421 - val_acc: 0.7819
# Epoch 29/35
# 83/83 [==============================] - ETA: 0s - loss: 0.3687 - acc: 0.8712
# Epoch 00029: val_acc did not improve from 0.82034
# 83/83 [==============================] - 205s 2s/step - loss: 0.3687 - acc: 0.8712 - val_loss: 0.5463 - val_acc: 0.8113
# Epoch 30/35
# 83/83 [==============================] - ETA: 0s - loss: 0.3751 - acc: 0.8723
# Epoch 00030: val_acc improved from 0.82034 to 0.83616, saving model to C:\Users\Jagjeet\AppML\Major Project Final\Pro_1.9_All_Datasets_Spectral_Attention Try\saved_models\best_model.h5
# 83/83 [==============================] - 201s 2s/step - loss: 0.3751 - acc: 0.8723 - val_loss: 0.4685 - val_acc: 0.8362
# Epoch 31/35
# 83/83 [==============================] - ETA: 0s - loss: 0.3511 - acc: 0.8768
# Epoch 00031: val_acc did not improve from 0.83616
# 83/83 [==============================] - 201s 2s/step - loss: 0.3511 - acc: 0.8768 - val_loss: 0.6681 - val_acc: 0.7921
# Epoch 32/35
# 83/83 [==============================] - ETA: 0s - loss: 0.3337 - acc: 0.8896
# Epoch 00032: val_acc did not improve from 0.83616
# 83/83 [==============================] - 204s 2s/step - loss: 0.3337 - acc: 0.8896 - val_loss: 0.5873 - val_acc: 0.7966
# Epoch 33/35
# 83/83 [==============================] - ETA: 0s - loss: 0.3229 - acc: 0.8945
# Epoch 00033: val_acc did not improve from 0.83616
# 83/83 [==============================] - 201s 2s/step - loss: 0.3229 - acc: 0.8945 - val_loss: 0.7018 - val_acc: 0.7808
# Epoch 34/35
# 83/83 [==============================] - ETA: 0s - loss: 0.3231 - acc: 0.8919
# Epoch 00034: val_acc did not improve from 0.83616
# 83/83 [==============================] - 200s 2s/step - loss: 0.3231 - acc: 0.8919 - val_loss: 0.6196 - val_acc: 0.7898
# Epoch 35/35
# 83/83 [==============================] - ETA: 0s - loss: 0.3200 - acc: 0.8930
# Epoch 00035: val_acc did not improve from 0.83616
# 83/83 [==============================] - 200s 2s/step - loss: 0.3200 - acc: 0.8930 - val_loss: 0.4775 - val_acc: 0.8339
# Loaded model from disk
# Test Accuracy:  0.8305084705352783
# Test loss:  0.5169785022735596
# 37/37 [==============================] - 13s 338ms/step - loss: 0.5170 - acc: 0.8305
# acc: 83.05%
# 74/74 [==============================] - 13s 173ms/step
#     actualvalues predictedvalues
# 170      disgust         disgust
# 171         fear            fear
# 172         calm         neutral
# 173      disgust        surprise
# 174          sad             sad
# 175     surprise        surprise
# 176     surprise        surprise
# 177      disgust         disgust
# 178        happy        surprise
# 179         fear            fear
#                  actualvalues
# predictedvalues
# angry                     175
# calm                       68
# disgust                   179
# fear                      154
# happy                     136
# neutral                   152
# sad                       131
# surprise                  185
#               precision    recall  f1-score   support
#
#        angry       0.86      0.86      0.86       175
#         calm       0.57      0.83      0.68        47
#      disgust       0.78      0.91      0.84       154
#         fear       0.86      0.79      0.82       169
#        happy       0.88      0.76      0.81       157
#      neutral       0.89      0.90      0.89       150
#          sad       0.91      0.72      0.80       165
#     surprise       0.78      0.89      0.83       163
#
#     accuracy                           0.83      1180
#    macro avg       0.82      0.83      0.82      1180
# weighted avg       0.84      0.83      0.83      1180

# %% [markdown]
# # 2D CNN MFCC with Augmentation

# %%
sampling_rate=44100
audio_duration=2.5
n_mfcc = 30
mfcc_aug = CNN_2D_prepare_data(ref, n = n_mfcc, aug = 1, mfcc = 1)
mfcc_aug = np.append(mfcc_aug, mfcc, axis=0)
label1 = pd.DataFrame(ref.label)
label2 = pd.DataFrame(ref.label)
result = label1.append(label2,sort=True)
result = result.reset_index()
result = result.drop(['index'], axis=1)
mfcc_aug2 = CNN_2D_prepare_data2(ref, n = n_mfcc, aug = 1, mfcc = 1)
mfcc_aug2 = np.append(mfcc_aug2, mfcc_aug, axis=0)
label2 = pd.DataFrame(ref.label)
result2 = result.append(label2,sort=True)
result2 = result2.reset_index()
result2 = result2.drop(['index'], axis=1)
# Out:
# 100%|██████████| 4720/4720 [06:47<00:00, 11.59it/s]
# 100%|██████████| 4720/4720 [07:48<00:00, 10.08it/s]

# %%
# Split between train and test 
X_train, X_test, y_train, y_test = train_test_split(mfcc_aug2
                                                    , result2
                                                    , test_size=0.25
                                                    , shuffle=True
                                                    , random_state=42
                                                   )

X_train, X_val, y_train, y_val = train_test_split(X_train
                                                  , y_train
                                                  , test_size=0.25
                                                  , shuffle=True
                                                  , random_state=42
                                                 )

# %% [markdown]
# 2D CNN Model

# %%
def get_2d_conv_model(n):
    ''' Create a standard deep 2D convolutional neural network'''
    nclass = 8
    inp = Input(shape=(n,216,1))  #2D matrix of 30 MFCC bands by 216 audio length.
    x = Convolution2D(64, (3,3), strides=(1, 1), padding="same")(inp)    #(4,10)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPool2D()(x)
    x = Dropout(rate=0.2)(x)
    
    x = Convolution2D(128, (3,3), strides=(1, 1), padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPool2D()(x)
    x = Dropout(rate=0.2)(x)
    
    x = Convolution2D(256, (3,3), strides=(1, 1), padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPool2D()(x)
    x = Dropout(rate=0.2)(x)
    
    x = Convolution2D(128, (3,3), strides=(1, 1), padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPool2D()(x)
    x = Dropout(rate=0.2)(x)
    
    x = Flatten()(x)
    
    out = Dense(nclass, activation=softmax)(x)
    model = models.Model(inputs=inp, outputs=out)
    
    opt = tf.keras.optimizers.Adam(learning_rate = 0.0001, decay=1e-6)
    model.compile(optimizer=opt, loss=losses.categorical_crossentropy, metrics=['acc'])
    return model

# Normalization as per the standard NN process
X_train_norm, X_test_norm, X_val_norm = data_normalization(X_train, X_test, X_val)

# one hot encode the target 
lb = LabelEncoder()
y_train_cat = np_utils.to_categorical(lb.fit_transform(y_train))    # for GPU
y_test_cat = np_utils.to_categorical(lb.fit_transform(y_test))      # for GPU
y_val_cat = np_utils.to_categorical(lb.fit_transform(y_val))        # for GPU

print(X_train.shape)
print(lb.classes_)

model = get_2d_conv_model(n_mfcc)
model.summary()

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=15)
model_name = 'best_model.h5'
save_dir = os.path.join(os.getcwd(), 'saved_models')
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
print('Save model and weights at %s ' % model_path)
mc = ModelCheckpoint(model_path, monitor='val_acc', mode='max', verbose=1, 
                     save_best_only=True)
model_history = model.fit(X_train_norm, y_train_cat, validation_data=(X_val_norm, y_val_cat), batch_size=32,
                          verbose = 1, epochs=35, callbacks=[es, mc])

results = get_results(model_history,model,X_test_norm,y_test_cat, ref.label.unique())
results.create_plot(model_history)

model_json = model.to_json()
with open("model_json.json", "w") as json_file:
    json_file.write(model_json)

# loading json and model architecture 
json_file = open('model_json.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
from keras.models import model_from_json
loaded_model = model_from_json(loaded_model_json, custom_objects={'SeqSelfAttention': SeqSelfAttention})

# load weights into new model
loaded_model.load_weights(model_path)#("saved_models/best_model.h5")
print("Loaded model from disk")

results.create_results(loaded_model)
finaldf = results.confusion_results(X_test_norm, y_test_cat, ref.label.unique(), loaded_model)

# Classification report 
classes = finaldf.actualvalues.unique()
classes.sort()    
print(classification_report(finaldf.actualvalues, finaldf.predictedvalues, target_names=classes))
# Out:
35
# 249/249 [==============================] - ETA: 0s - loss: 0.2028 - acc: 0.9328
# Epoch 00035: val_acc did not improve from 0.85687
# 249/249 [==============================] - 588s 2s/step - loss: 0.2028 - acc: 0.9328 - val_loss: 0.5185 - val_acc: 0.8331
# Loaded model from disk
# Test Accuracy:  0.8556497097015381
# Test loss:  0.4275977909564972
# 111/111 [==============================] - 36s 320ms/step - loss: 0.4276 - acc: 0.8556
# acc: 85.56%
# 222/222 [==============================] - 39s 176ms/step
#     actualvalues predictedvalues
# 170          sad             sad
# 171      neutral         neutral
# 172      disgust           happy
# 173        happy           happy
# 174         fear            fear
# 175      disgust         neutral
# 176        angry             sad
# 177     surprise        surprise
# 178        happy           happy
# 179     surprise        surprise
#                  actualvalues
# predictedvalues
# angry                     438
# calm                      216
# disgust                   487
# fear                      430
# happy                     476
# neutral                   546
# sad                       467
# surprise                  480
#               precision    recall  f1-score   support
#
#        angry       0.95      0.86      0.90       483
#         calm       0.63      0.87      0.73       156
#      disgust       0.89      0.88      0.88       492
#         fear       0.92      0.79      0.85       496
#        happy       0.84      0.83      0.84       481
#      neutral       0.82      0.93      0.87       483
#          sad       0.85      0.80      0.83       496
#     surprise       0.85      0.90      0.87       453
#
#     accuracy                           0.86      3540
#    macro avg       0.84      0.86      0.85      3540
# weighted avg       0.86      0.86      0.86      3540

# %% [markdown]
# 2D CNN LSTM Model

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
def get_2d_conv_LSTM_model(n):
    ''' Create a standard deep 2D convolutional neural network'''
    nclass = 8
    inp = Input(shape=(n,216,1))  #2D matrix of 30 MFCC bands by 216 audio length.
    x = Convolution2D(64, (3,3), strides=(1, 1), padding="same")(inp)    #(4,10)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPool2D()(x)
    x = Dropout(rate=0.2)(x)
    
    x = Convolution2D(128, (3,3), strides=(1, 1), padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPool2D()(x)
    x = Dropout(rate=0.2)(x)
    
    x = Convolution2D(256, (3,3), strides=(1, 1), padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPool2D()(x)
    x = Dropout(rate=0.2)(x)
    
    x = Convolution2D(128, (3,3), strides=(1, 1), padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPool2D()(x)
    x = Dropout(rate=0.2)(x)
    
    x = Reshape((-1, 128))(x)
    
    #LSTM
    x = LSTM(128)(x)
    
    out = Dense(nclass, activation=softmax)(x)
    model = models.Model(inputs=inp, outputs=out)
    
    opt = tf.keras.optimizers.Adam(learning_rate = 0.0001, decay=1e-6)
    model.compile(optimizer=opt, loss=losses.categorical_crossentropy, metrics=['acc'])
    return model


# Normalization as per the standard NN process
X_train_norm, X_test_norm, X_val_norm = data_normalization(X_train, X_test, X_val)

# one hot encode the target 
lb = LabelEncoder()
y_train_cat = np_utils.to_categorical(lb.fit_transform(y_train))    # for GPU
y_test_cat = np_utils.to_categorical(lb.fit_transform(y_test))      # for GPU
y_val_cat = np_utils.to_categorical(lb.fit_transform(y_val))        # for GPU


print(X_train.shape)
print(lb.classes_)

model = get_2d_conv_LSTM_model(n_mfcc)
model.summary()

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=15)
model_name = 'best_model.h5'
save_dir = os.path.join(os.getcwd(), 'saved_models')
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
print('Save model and weights at %s ' % model_path)
mc = ModelCheckpoint(model_path, monitor='val_acc', mode='max', verbose=1, 
                     save_best_only=True)
model_history = model.fit(X_train_norm, y_train_cat, validation_data=(X_val_norm, y_val_cat), batch_size=32,
                          verbose = 1, epochs=35, callbacks=[es, mc])

results = get_results(model_history,model,X_test_norm,y_test_cat, ref.label.unique())
results.create_plot(model_history)

model_json = model.to_json()
with open("model_json.json", "w") as json_file:
    json_file.write(model_json)

# loading json and model architecture 
json_file = open('model_json.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
from keras.models import model_from_json
loaded_model = model_from_json(loaded_model_json, custom_objects={'SeqSelfAttention': SeqSelfAttention})

# load weights into new model
loaded_model.load_weights(model_path)#("saved_models/best_model.h5")
print("Loaded model from disk")

results.create_results(loaded_model)
finaldf = results.confusion_results(X_test_norm, y_test_cat, ref.label.unique(), loaded_model)

# Classification report 
classes = finaldf.actualvalues.unique()
classes.sort()    
print(classification_report(finaldf.actualvalues, finaldf.predictedvalues, target_names=classes))
# Out:
# Epoch 00034: val_acc did not improve from 0.87156
# 249/249 [==============================] - 615s 2s/step - loss: 0.1972 - acc: 0.9317 - val_loss: 0.4226 - val_acc: 0.8637
# Epoch 35/35
# 249/249 [==============================] - ETA: 0s - loss: 0.1908 - acc: 0.9348
# Epoch 00035: val_acc did not improve from 0.87156
# 249/249 [==============================] - 606s 2s/step - loss: 0.1908 - acc: 0.9348 - val_loss: 0.4447 - val_acc: 0.8516
# Loaded model from disk
# Test Accuracy:  0.8692090511322021
# Test loss:  0.37517890334129333
# 111/111 [==============================] - 37s 338ms/step - loss: 0.3752 - acc: 0.8692
# acc: 86.92%
# 222/222 [==============================] - 39s 174ms/step
#     actualvalues predictedvalues
# 170          sad             sad
# 171      neutral         neutral
# 172      disgust           happy
# 173        happy           happy
# 174         fear            fear
# 175      disgust             sad
# 176        angry             sad
# 177     surprise        surprise
# 178        happy           happy
# 179     surprise        surprise
#                  actualvalues
# predictedvalues
# angry                     517
# calm                      200
# disgust                   433
# fear                      428
# happy                     483
# neutral                   518
# sad                       509
# surprise                  452
#               precision    recall  f1-score   support
#
#        angry       0.87      0.93      0.90       483
#         calm       0.69      0.88      0.78       156
#      disgust       0.94      0.83      0.88       492
#         fear       0.93      0.80      0.86       496
#        happy       0.85      0.85      0.85       481
#      neutral       0.87      0.93      0.90       483
#          sad       0.83      0.85      0.84       496
#     surprise       0.90      0.89      0.90       453
#
#     accuracy                           0.87      3540
#    macro avg       0.86      0.87      0.86      3540
# weighted avg       0.87      0.87      0.87      3540

# %% [markdown]
# 2D CNN LSTM with Self-Attention Model

# %%
def get_2d_conv_LSTM_atten_model(n):
    ''' Create a standard deep 2D convolutional neural network'''
    nclass = 8
    inp = Input(shape=(n,216,1))  #2D matrix of 30 MFCC bands by 216 audio length.
    x = Convolution2D(64, (3,3), strides=(1, 1), padding="same")(inp)    #(4,10)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPool2D()(x)
    x = Dropout(rate=0.2)(x)
    
    x = Convolution2D(128, (3,3), strides=(1, 1), padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPool2D()(x)
    x = Dropout(rate=0.2)(x)
    
    x = Convolution2D(256, (3,3), strides=(1, 1), padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPool2D()(x)
    x = Dropout(rate=0.2)(x)
    
    x = Convolution2D(128, (3,3), strides=(1, 1), padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPool2D()(x)
    x = Dropout(rate=0.2)(x)
    
    x = Reshape((-1, 128))(x)
    #LSTM
    x = LSTM(32, return_sequences=True)(x)
    x = SeqSelfAttention(attention_activation ='tanh')(x)
    x = LSTM(32, return_sequences=False)(x)
    
    
    out = Dense(nclass, activation=softmax)(x)
    model = models.Model(inputs=inp, outputs=out)
    
    opt = tf.keras.optimizers.Adam(learning_rate = 0.0001, decay=1e-6)
    model.compile(optimizer=opt, loss=losses.categorical_crossentropy, metrics=['acc'])
    return model


# Normalization as per the standard NN process
X_train_norm, X_test_norm, X_val_norm = data_normalization(X_train, X_test, X_val)

# one hot encode the target 
lb = LabelEncoder()
y_train_cat = np_utils.to_categorical(lb.fit_transform(y_train))    # for GPU
y_test_cat = np_utils.to_categorical(lb.fit_transform(y_test))      # for GPU
y_val_cat = np_utils.to_categorical(lb.fit_transform(y_val))        # for GPU


print(X_train.shape)
print(lb.classes_)

model = get_2d_conv_LSTM_atten_model(n_mfcc)
model.summary()
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=15)
model_name = 'best_model.h5'
save_dir = os.path.join(os.getcwd(), 'saved_models')
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
print('Save model and weights at %s ' % model_path)

mc = ModelCheckpoint(model_path, monitor='val_acc', mode='max', verbose=1, 
                     save_best_only=True)
model_history = model.fit(X_train_norm, y_train_cat, validation_data=(X_val_norm, y_val_cat), batch_size=16,
                          verbose = 1, epochs=35, callbacks=[es, mc])

results = get_results(model_history,model,X_test_norm,y_test_cat, ref.label.unique())
results.create_plot(model_history)

model_json = model.to_json()
with open("model_json.json", "w") as json_file:
    json_file.write(model_json)

# loading json and model architecture 
json_file = open('model_json.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
from keras.models import model_from_json
loaded_model = model_from_json(loaded_model_json, custom_objects={'SeqSelfAttention': SeqSelfAttention})

# load weights into new model
loaded_model.load_weights(model_path)#("saved_models/best_model.h5")
print("Loaded model from disk")

results.create_results(loaded_model)
finaldf = results.confusion_results(X_test_norm,y_test_cat, ref.label.unique(), loaded_model)

# Classification report 
classes = finaldf.actualvalues.unique()
classes.sort()    
print(classification_report(finaldf.actualvalues, finaldf.predictedvalues, target_names=classes))
# Out:
# (7965, 30, 216, 1)
# ['angry' 'calm' 'disgust' 'fear' 'happy' 'neutral' 'sad' 'surprise']
# Model: "functional_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 30, 216, 1)]      0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 30, 216, 64)       640
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 30, 216, 64)       256
# _________________________________________________________________
# activation_20 (Activation)   (None, 30, 216, 64)       0
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 15, 108, 64)       0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 15, 108, 64)       0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 15, 108, 128)      73856
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 15, 108, 128)      512
# _________________________________________________________________
# activation_21 (Activation)   (None, 15, 108, 128)      0
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 7, 54, 128)        0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 7, 54, 128)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 7, 54, 256)        295168
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 7, 54, 256)        1024
# _________________________________________________________________
# activation_22 (Activation)   (None, 7, 54, 256)        0
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 3, 27, 256)        0
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 3, 27, 256)        0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 3, 27, 128)        295040
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 3, 27, 128)        512
# _________________________________________________________________
# activation_23 (Activation)   (None, 3, 27, 128)        0
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 1, 13, 128)        0
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 1, 13, 128)        0
# _________________________________________________________________
# reshape_3 (Reshape)          (None, 13, 128)           0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 13, 32)            20608
# _________________________________________________________________
# seq_self_attention_1 (SeqSel (None, None, 32)          2113
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 32)                8320
# _________________________________________________________________
# dense_5 (Dense)              (None, 8)                 264
# =================================================================
# Total params: 698,313
# Trainable params: 697,161
# Non-trainable params: 1,152
# _________________________________________________________________
# Save model and weights at C:\Users\Jagjeet\AppML\Major Project Final\Pro_1.9_All_Datasets_Spectral_Attention Try\saved_models\best_model.h5
# Epoch 1/35
# 498/498 [==============================] - ETA: 0s - loss: 1.7031 - acc: 0.4210
# Epoch 00001: val_acc improved from -inf to 0.40452, saving model to C:\Users\Jagjeet\AppML\Major Project Final\Pro_1.9_All_Datasets_Spectral_Attention Try\saved_models\best_model.h5
# 498/498 [==============================] - 626s 1s/step - loss: 1.7031 - acc: 0.4210 - val_loss: 1.6634 - val_acc: 0.4045
# Epoch 2/35
# 498/498 [==============================] - ETA: 0s - loss: 1.2232 - acc: 0.6113
# Epoch 00002: val_acc improved from 0.40452 to 0.62448, saving model to C:\Users\Jagjeet\AppML\Major Project Final\Pro_1.9_All_Datasets_Spectral_Attention Try\saved_models\best_model.h5
# 498/498 [==============================] - 618s 1s/step - loss: 1.2232 - acc: 0.6113 - val_loss: 1.1537 - val_acc: 0.6245
# Epoch 3/35
# 498/498 [==============================] - ETA: 0s - loss: 0.9886 - acc: 0.6760
# Epoch 00003: val_acc improved from 0.62448 to 0.71525, saving model to C:\Users\Jagjeet\AppML\Major Project Final\Pro_1.9_All_Datasets_Spectral_Attention Try\saved_models\best_model.h5
# 498/498 [==============================] - 618s 1s/step - loss: 0.9886 - acc: 0.6760 - val_loss: 0.8663 - val_acc: 0.7153
# Epoch 4/35
# 498/498 [==============================] - ETA: 0s - loss: 0.8625 - acc: 0.7111
# Epoch 00004: val_acc did not improve from 0.71525
# 498/498 [==============================] - 644s 1s/step - loss: 0.8625 - acc: 0.7111 - val_loss: 0.8571 - val_acc: 0.7115
# Epoch 5/35
# 498/498 [==============================] - ETA: 0s - loss: 0.7859 - acc: 0.7288
# Epoch 00005: val_acc improved from 0.71525 to 0.74840, saving model to C:\Users\Jagjeet\AppML\Major Project Final\Pro_1.9_All_Datasets_Spectral_Attention Try\saved_models\best_model.h5
# 498/498 [==============================] - 630s 1s/step - loss: 0.7859 - acc: 0.7288 - val_loss: 0.7543 - val_acc: 0.7484
# Epoch 6/35
# 498/498 [==============================] - ETA: 0s - loss: 0.7198 - acc: 0.7537
# Epoch 00006: val_acc improved from 0.74840 to 0.77476, saving model to C:\Users\Jagjeet\AppML\Major Project Final\Pro_1.9_All_Datasets_Spectral_Attention Try\saved_models\best_model.h5
# 498/498 [==============================] -
# Epoch 00029: val_acc improved from 0.85499 to 0.86855, saving model to C:\Users\Jagjeet\AppML\Major Project Final\Pro_1.9_All_Datasets_Spectral_Attention Try\saved_models\best_model.h5
# 498/498 [==============================] - 620s 1s/step - loss: 0.2688 - acc: 0.9094 - val_loss: 0.3878 - val_acc: 0.8685
# Epoch 30/35
# 498/498 [==============================] - ETA: 0s - loss: 0.2580 - acc: 0.9117
# Epoch 00030: val_acc did not improve from 0.86855
# 498/498 [==============================] - 620s 1s/step - loss: 0.2580 - acc: 0.9117 - val_loss: 0.4046 - val_acc: 0.8573
# Epoch 31/35
# 498/498 [==============================] - ETA: 0s - loss: 0.2478 - acc: 0.9170
# Epoch 00031: val_acc did not improve from 0.86855
# 498/498 [==============================] - 613s 1s/step - loss: 0.2478 - acc: 0.9170 - val_loss: 0.4453 - val_acc: 0.8490
# Epoch 32/35
# 498/498 [==============================] - ETA: 0s - loss: 0.2458 - acc: 0.9158
# Epoch 00032: val_acc did not improve from 0.86855
# 498/498 [==============================] - 630s 1s/step - loss: 0.2458 - acc: 0.9158 - val_loss: 0.3914 - val_acc: 0.8682
# Epoch 33/35
# 498/498 [==============================] - ETA: 0s - loss: 0.2286 - acc: 0.9224
# Epoch 00033: val_acc did not improve from 0.86855
# 498/498 [==============================] - 623s 1s/step - loss: 0.2286 - acc: 0.9224 - val_loss: 0.4212 - val_acc: 0.8606
# Epoch 34/35
# 498/498 [==============================] - ETA: 0s - loss: 0.2215 - acc: 0.9254
# Epoch 00034: val_acc did not improve from 0.86855
# 498/498 [==============================] - 618s 1s/step - loss: 0.2215 - acc: 0.9254 - val_loss: 0.4119 - val_acc: 0.8637
# Epoch 35/35
# 498/498 [==============================] - ETA: 0s - loss: 0.2135 - acc: 0.9279
# Epoch 00035: val_acc did not improve from 0.86855
# 498/498 [==============================] - 623s 1s/step - loss: 0.2135 - acc: 0.9279 - val_loss: 0.4271 - val_acc: 0.8588
# Loaded model from disk
# Test Accuracy:  0.8601694703102112
# Test loss:  0.4177573025226593
# 111/111 [==============================] - 37s 331ms/step - loss: 0.4178 - acc: 0.8602
# acc: 86.02%
# 222/222 [==============================] - 37s 169ms/step
#     actualvalues predictedvalues
# 170          sad             sad
# 171      neutral         neutral
# 172      disgust           happy
# 173        happy           happy
# 174         fear            fear
# 175      disgust         disgust
# 176        angry             sad
# 177     surprise        surprise
# 178        happy           happy
# 179     surprise        surprise
#                  actualvalues
# predictedvalues
# angry                     473
# calm                      202
# disgust                   525
# fear                      516
# happy                     438
# neutral                   412
# sad                       500
# surprise                  474
#               precision    recall  f1-score   support
#
#        angry       0.91      0.89      0.90       483
#         calm       0.67      0.87      0.75       156
#      disgust       0.85      0.90      0.87       492
#         fear       0.83      0.87      0.85       496
#        happy       0.92      0.83      0.87       481
#      neutral       0.93      0.80      0.86       483
#          sad       0.82      0.82      0.82       496
#     surprise       0.87      0.91      0.89       453
#
#     accuracy                           0.86      3540
#    macro avg       0.85      0.86      0.85      3540
# weighted avg       0.87      0.86      0.86      3540
